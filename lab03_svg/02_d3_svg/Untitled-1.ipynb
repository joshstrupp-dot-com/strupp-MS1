# %%
# %pip install matplotlib
import matplotlib
import matplotlib.pyplot as plt

cities = [
    { "name": "London", "population": 8674000 },
    { "name": "New York", "population": 8406000 },
    { "name": "Sydney", "population": 4293000 },
    { "name": "Paris", "population": 2244000 },
    { "name": "Beijing", "population": 11510000 },
]

city_names = [city["name"] for city in cities]
city_populations = [city["population"] for city in cities]

plt.bar(city_names, city_populations)
plt.xlabel("City")
plt.ylabel("Population")
plt.title("Population of Cities")
plt.show()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.9.2-cp311-cp311-macosx_11_0_arm64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 6.5 MB/s eta 0:00:0000:0100:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp311-cp311-macosx_11_0_arm64.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 6.1 MB/s eta 0:00:0000:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.53.1-cp311-cp311-macosx_11_0_arm64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 6.8 MB/s eta 0:00:00a 0:00:01m
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp311-cp311-macosx_11_0_arm64.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23 in /Users/joshstrupp/Library/Python/3.11/lib/python/site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in /Users/joshstrupp/Library/Python/3.11/lib/python/site-packages (from matplotlib) (23.1)
# Collecting pillow>=8
#   Downloading pillow-10.4.0-cp311-cp311-macosx_11_0_arm64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 7.6 MB/s eta 0:00:00a 0:00:01m
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /Users/joshstrupp/Library/Python/3.11/lib/python/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/joshstrupp/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.7 matplotlib-3.9.2 pillow-10.4.0 pyparsing-3.1.4
#
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Matplotlib is building the font cache; this may take a moment.
